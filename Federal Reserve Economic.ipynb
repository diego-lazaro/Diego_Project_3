# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
#from config import api_key

# %%
# Define an empty list to fetch data
fred_data = []

# Create Fred API

# Start date
earliest_realtime_start = 1980-1-1

# End date
latest_realtime_end = 1999-12-31

# Max amount of results
max_request_results = 1000

nan_char = '.'
# main URL used
root_url = "https://api.stlouisfed.org/fred"

# Create URL with endpoints: API 8d4aa278dda16f4a68ce9443e8feda2a
fred_url = "https://api.stlouisfed.org/fred/series/observations?series_id=GDP&api_key=8d4aa278dda16f4a68ce9443e8feda2a&file_type=json"

# Request data
fred_data = requests.get(fred_url)
fred_data = fred_data.json()
fred_data
# Out:
# {'realtime_start': '2023-05-29',
#  'realtime_end': '2023-05-29',
#  'observation_start': '1600-01-01',
#  'observation_end': '9999-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 309,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '2023-05-29',
#    'realtime_end': '2023-05-29',
#    'date': '1946-01-01',
#    'value': '.'},
#   {'realtime_start': '2023-05-29',
#    'realtime_end': '2023-05-29',
#    'date': '1946-04-01',
#    'value': '.'},
#   {'realtime_start': '2023-05-29',
#    'realtime_end': '2023-05-29',
#    'date': '1946-07-01',
#    'value': '.'},
#   {'realtime_start': '2023-05-29',
#    'realtime_end': '2023-05-29',
#    'date': '1946-10-01',
#    'value': '.'},
#   {'realtime_start': '2023-05-29',
#    'realtime_end': '2023-05-29',
#    'date': '1947-01-01',
#    'value': '243.164'},
#   {'realtime_start': '2023-05-29',
# ...

# %%
# Convert Datasets to Dataframe
fred_df = pd.DataFrame(fred_data["observations"])
fred_df.tail()
# Out:
#     realtime_start realtime_end        date      value
# 304     2023-05-29   2023-05-29  2022-01-01   24740.48
# 305     2023-05-29   2023-05-29  2022-04-01  25248.476
# 306     2023-05-29   2023-05-29  2022-07-01  25723.941
# 307     2023-05-29   2023-05-29  2022-10-01  26137.992
# 308     2023-05-29   2023-05-29  2023-01-01  26486.287

# %%
# Create an empty dataframe to hold all data
clean_fred_df = pd.DataFrame(columns= ["Realtime_Start",
                            "Realtime_end",
                            "Date",
                            "Value"])
clean_fred_df
# Out:
# Empty DataFrame
# Columns: [Realtime_Start, Realtime_end, Date, Value]
# Index: []

# %%
# Clean dataframe
